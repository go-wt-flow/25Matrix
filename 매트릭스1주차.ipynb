# %% [markdown]
# <a href="https://colab.research.google.com/github/go-wt-flow/25Matrix/blob/main/%EB%A7%A4%ED%8A%B8%EB%A6%AD%EC%8A%A41%EC%A3%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1주차 - 9월 17일
#
#
# ---
#
# ## 알아두면 좋은 사이트
# - Kaggle
# - DACON

# %% [markdown]
# ## 데이터 다루기

# %% [markdown]
# Feature Data
# - 모델 학습에 사용할때 참고하는 독립변수
# - 여러 개의 속성을 가질 수 있음
#
# Target Data
# - 종속변수
# - 모델이 예측하려는 값, 맞춰야 하는 정답

# %%
# 데이터 불러오기
import pandas as pd

df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

# %% [markdown]
# info(), describe()
# - 데이터셋 정보 확인하기

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 652 entries, 0 to 651
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        652 non-null    object
#  1   Pregnancies               652 non-null    int64
#  2   Glucose                   652 non-null    int64
#  3   BloodPressure             652 non-null    int64
#  4   SkinThickness             652 non-null    int64
#  5   Insulin                   652 non-null    int64
#  6   BMI                       652 non-null    float64
#  7   DiabetesPedigreeFunction  652 non-null    float64
#  8   Age                       652 non-null    int64
#  9   Outcome                   652 non-null    int64
# dtypes: float64(2), int64(7), object(1)
# memory usage: 51.1+ KB

# %%
df_train.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   652.000000  652.000000     652.000000     652.000000  652.000000
# mean      3.923313  120.946319      68.895706      20.440184   80.878834
# std       3.327529   31.992394      19.183843      15.918604  117.748315
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      64.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   34.000000
# 75%       6.000000  142.000000      80.000000      32.000000  126.000000
# max      15.000000  199.000000     114.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  652.000000                652.000000  652.000000  652.000000
# mean    31.947393                  0.465133   33.510736    0.349693
# std      7.460975                  0.329496   11.824817    0.477239
# ...

# %% [markdown]
# head()
# - 데이터셋의 초반 데이터 몇 개를 보여줌
# - 디폴트값 5, 함수의 인자로 조정 가능

# %%
df_train.head()
# Out:
#           ID  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0  TRAIN_000            4      103             60             33      192
# 1  TRAIN_001           10      133             68              0        0
# 2  TRAIN_002            4      112             78             40        0
# 3  TRAIN_003            1      119             88             41      170
# 4  TRAIN_004            1      114             66             36      200
#
#     BMI  DiabetesPedigreeFunction  Age  Outcome
# 0  24.0                     0.966   33        0
# 1  27.0                     0.245   36        0
# 2  39.4                     0.236   38        0
# 3  45.3                     0.507   26        0
# 4  38.1                     0.289   21        0

# %%
df_train.head(10)
# Out:
#           ID  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0  TRAIN_000            4      103             60             33      192
# 1  TRAIN_001           10      133             68              0        0
# 2  TRAIN_002            4      112             78             40        0
# 3  TRAIN_003            1      119             88             41      170
# 4  TRAIN_004            1      114             66             36      200
# 5  TRAIN_005            3       78             50             32       88
# 6  TRAIN_006            1       91             54             25      100
# 7  TRAIN_007            5      117             86             30      105
# 8  TRAIN_008            1      124             60             32        0
# 9  TRAIN_009            1      167             74             17      144
#
#     BMI  DiabetesPedigreeFunction  Age  Outcome
# 0  24.0                     0.966   33        0
# 1  27.0                     0.245   36        0
# ...

# %% [markdown]
# tail()
# - 데이터셋의 마지막 데이터 몇 개를 보여줌

# %%
df_train.tail()
# Out:
#             ID  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 647  TRAIN_647            1       91             64             24        0
# 648  TRAIN_648           10      122             68              0        0
# 649  TRAIN_649            8       84             74             31        0
# 650  TRAIN_650            2       81             72             15       76
# 651  TRAIN_651            1      107             68             19        0
#
#       BMI  DiabetesPedigreeFunction  Age  Outcome
# 647  29.2                     0.192   21        0
# 648  31.2                     0.258   41        0
# 649  38.3                     0.457   39        0
# 650  30.1                     0.547   25        0
# 651  26.5                     0.165   24        0

# %% [markdown]
# 데이터셋의 속성들
# - shape: 데이터 크기(행, 열 수) 출력
# - columns: 열 이름 출력
# - dtypes: 데이터 타입 출력

# %%
df_train.shape
# Out:
# (652, 10)

# %%
df_train.columns
# Out:
# Index(['ID', 'Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness',
#        'Insulin', 'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
df_train.dtypes
# Out:
# ID                           object
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %% [markdown]
# ## 인덱싱과 슬라이싱
# 숫자 인덱스 기준: df.iloc[행번호, 열번호]
# 라벨(이름) 기준: df.loc[행라벨, 열라벨]

# %%
df_train.iloc[:, 3]
# Out:
# 0      60
# 1      68
# 2      78
# 3      88
# 4      66
#        ..
# 647    64
# 648    68
# 649    74
# 650    72
# 651    68
# Name: BloodPressure, Length: 652, dtype: int64

# %%
df_train.loc[:, "Age"]
# Out:
# 0      33
# 1      36
# 2      38
# 3      26
# 4      21
#        ..
# 647    21
# 648    41
# 649    39
# 650    25
# 651    24
# Name: Age, Length: 652, dtype: int64

# %% [markdown]
# ## 기타 유용 코드
# - print(train['Outcome']) : 특정 열 출력
# - df_new = df[조건식]: 원하는 조건으로 필터링하기

# %%
diabetes = df_train[df_train['Outcome']==1]
diabetes.head()
# Out:
#            ID  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 5   TRAIN_005            3       78             50             32       88
# 9   TRAIN_009            1      167             74             17      144
# 10  TRAIN_010            4      145             82             18        0
# 11  TRAIN_011            8      124             76             24      600
# 12  TRAIN_012            4      184             78             39      277
#
#      BMI  DiabetesPedigreeFunction  Age  Outcome
# 5   31.0                     0.248   26        1
# 9   23.4                     0.447   33        1
# 10  32.5                     0.235   70        1
# 11  28.7                     0.687   52        1
# 12  37.0                     0.264   31        1

# %% [markdown]
# - rename(): 열 이름 변경

# %%
df_train_renamed = df_train.rename(columns = {'Age': '나이'})
df_train_renamed.head()
# Out:
#           ID  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0  TRAIN_000            4      103             60             33      192
# 1  TRAIN_001           10      133             68              0        0
# 2  TRAIN_002            4      112             78             40        0
# 3  TRAIN_003            1      119             88             41      170
# 4  TRAIN_004            1      114             66             36      200
#
#     BMI  DiabetesPedigreeFunction  나이  Outcome
# 0  24.0                     0.966  33        0
# 1  27.0                     0.245  36        0
# 2  39.4                     0.236  38        0
# 3  45.3                     0.507  26        0
# 4  38.1                     0.289  21        0

# %% [markdown]
# - sort_values(): 오름차순 정렬
# - sort_values(ascending=False): 내림차순 정렬

# %%
df_train.sort_values(by='Age')
# Out:
#             ID  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 647  TRAIN_647            1       91             64             24        0
# 4    TRAIN_004            1      114             66             36      200
# 8    TRAIN_008            1      124             60             32        0
# 54   TRAIN_054            0      138             60             35      167
# 63   TRAIN_063            1       99             58             10        0
# ..         ...          ...      ...            ...            ...      ...
# 533  TRAIN_533            5      136             82              0        0
# 603  TRAIN_603            5      132             80              0        0
# 10   TRAIN_010            4      145             82             18        0
# 255  TRAIN_255            2      119              0              0        0
# 14   TRAIN_014            9      134             74             33       60
#
#       BMI  DiabetesPedigreeFunction  Age  Outcome
# ...

# %% [markdown]
# train.csv는 충분히 했으니, test.csv에 대해서
# 1. pandas 라이브러리 불러온 후, test.csv를 test라는 이름의 변수로 불러오기
# 2. test에 대하여 오늘 배운 메서드(함수) 및 속성들 확인
# 3. 인덱싱 연습: test의 10번째 데이터만을 출력하는 코드 작성해보기
# 4. 슬라이싱 연습: test의 5~15번째 행, 2~4번째 열 만을 출력하는 코드 작성해보기
# 5. 조건에 맞춘 필터링: test에서 ‘Age’열 50세 이상인 것들을 test_over50이라는 이름으로 저장해보기
# 6. 열 이름 변경: test의 모든 칼럼명을 한국어로 바꾸고 test_korean로 저장해보기

# %%
test = pd.read_csv("test.csv")

test.head()
# Out:
#          ID  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 0  TEST_000            5      112             66              0        0
# 1  TEST_001            3      107             62             13       48
# 2  TEST_002            3      113             44             13        0
# 3  TEST_003            6      190             92              0        0
# 4  TEST_004            1      107             72             30       82
#
#     BMI  DiabetesPedigreeFunction  Age
# 0  37.8                     0.261   41
# 1  22.9                     0.678   23
# 2  22.4                     0.140   22
# 3  35.5                     0.278   66
# 4  30.8                     0.821   24

# %%
test.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   116.000000  116.000000     116.000000     116.000000  116.000000
# mean      3.405172  120.603448      70.284483      21.077586   73.732759
# std       3.580086   31.998065      20.341350      16.198846  100.249199
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000  100.000000      62.000000       0.000000    0.000000
# 50%       2.000000  113.000000      72.000000      22.500000   20.500000
# 75%       6.000000  133.500000      82.000000      33.000000  131.250000
# max      17.000000  197.000000     122.000000      63.000000  545.000000
#
#               BMI  DiabetesPedigreeFunction         Age
# count  116.000000                116.000000  116.000000
# mean    32.246552                  0.509776   31.724138
# std      9.969182                  0.340413   11.320306
# min      0.000000                  0.078000   21.000000
# ...

# %%
test.shape
# Out:
# (116, 9)

# %%
test.iloc[9,:]
# Out:
# ID                          TEST_009
# Pregnancies                        0
# Glucose                          109
# BloodPressure                     88
# SkinThickness                     30
# Insulin                            0
# BMI                             32.5
# DiabetesPedigreeFunction       0.855
# Age                               38
# Name: 9, dtype: object

# %%
test.iloc[4:15, 1:4]
# Out:
#     Pregnancies  Glucose  BloodPressure
# 4             1      107             72
# 5             1       79             60
# 6             0      188             82
# 7            12      140             82
# 8             0       93            100
# 9             0      109             88
# 10            1      126             56
# 11            5      155             84
# 12            2      100             54
# 13            4       95             60
# 14            7      106             92

# %%
test_over50 = test[test['Age']>50]
test_over50.head()
# Out:
#           ID  Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# 3   TEST_003            6      190             92              0        0
# 7   TEST_007           12      140             82             43      325
# 20  TEST_020            7      181             84             21      192
# 33  TEST_033           11      127            106              0        0
# 42  TEST_042            4      146             92              0        0
#
#      BMI  DiabetesPedigreeFunction  Age
# 3   35.5                     0.278   66
# 7   39.2                     0.528   58
# 20  35.9                     0.586   51
# 33  39.0                     0.190   51
# 42  31.2                     0.539   61

# %%
test_korean = test.rename(columns = {'Pregnancies':'임신여부'})
test_korean = test_korean.rename(columns = {'Glucose':'글루코스'})
test_korean = test_korean.rename(columns = {'BloodPressure':'혈압'})
test_korean = test_korean.rename(columns = {'SkinThickness':'피부 두께'})
test_korean = test_korean.rename(columns = {'Insulin':'인슐린'})
test_korean = test_korean.rename(columns = {'BMI':'체질량지수'})
test_korean = test_korean.rename(columns = {'DiabetesPedigreeFunction':'피마 인디언 예측'})
test_korean = test_korean.rename(columns = {'Age':'나이'})

test_korean.head()
# Out:
#          ID  임신여부  글루코스  혈압  피부 두께  인슐린  체질량지수  피마 인디언 예측  나이
# 0  TEST_000     5   112  66      0    0   37.8      0.261  41
# 1  TEST_001     3   107  62     13   48   22.9      0.678  23
# 2  TEST_002     3   113  44     13    0   22.4      0.140  22
# 3  TEST_003     6   190  92      0    0   35.5      0.278  66
# 4  TEST_004     1   107  72     30   82   30.8      0.821  24
